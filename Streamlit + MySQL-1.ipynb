# %%
## Import Bin 
import pandas as pd 
import streamlit as st
import mysql.connector

# %%
mydb=mysql.connector.connect(
    host="localhost",
    user="root",
    password="Momiloveu2!",
    database="Khichdi_2"
)
print(mydb)

# %%
st.set_page_config("Khichdi 2.0")
st.markdown("<h3 style='Text-align:center;'> Khichdi 2.0 </h1>",unsafe_allow_html=True)

t1, t2, t3, t4, t5=st.tabs(["📝 Create Account", "🔐 Login", "🔄 Forgot Password", "We're Hiring!", "🔐 Account Details"])

with t1:
    st.subheader("📝 Create Account")
    username=st.text_input("Username ↓")
    email=st.text_input("Email ↓")
    phone=st.number_input("Phone Number ↓")
    password=st.text_input("Password ↓",type="password")
    confirm = st.text_input("Confirm Password ↓",type="password")

    if st.button("Sign Up"):
        if not username or not email or not password or not phone:
            st.warning("Please fill all fields...")
        elif password!=confirm:
            st.error("Passwords do not match!")
        else:
            mydb=mysql.connector.connect(
            host="localhost",
            user="root",
            password="Momiloveu2!",
            database="Khichdi_2"
            )
            cur=mydb.cursor()

            cur.execute("select * from Khichdi_Users")
            data=cur.fetchall()
            cur.close()
            df=pd.DataFrame(data,columns=["username","Email","password","Phonenumber"])
            if username in df["username"].values:
                st.error("Username already exists!")
            else:
                mydb=mysql.connector.connect(
                host="localhost",
                user="root",
                password="Momiloveu2!",
                database="Khichdi_2"
                )
                cur=mydb.cursor()

                sql="insert into Khichdi_Users (username,Email,password,Phonenumber) values (%s,%s,%s,%s,%s)"
                val=(df["username"],df["Email"],df["password"],df["Phonenumber"])

                cur.execute(sql,val)

                mydb.commit()
                st.success("Account created successfully!")
                st.sucess("You can now 🔐 Login...")
# Out:
# 2026-02-12 17:35:46.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 17:35:46.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 17:35:46.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 17:35:46.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 17:35:46.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 17:35:46.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-12 17:35:46.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
